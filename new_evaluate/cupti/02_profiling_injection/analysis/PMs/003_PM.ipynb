# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
data_path = '../../data/postprocessed/PM/'

mapping_table = {
    'backprop': 'Backpropagation algorithm',
    'gaussian': 'Gaussian Elimination',
    'gpu': 'Stream Cluster',
    'lenet': 'Lenet5',
    'gpuburn': 'GPU-burn'
}

data_sheet = pd.DataFrame()
for csv_name in [file for file in os.listdir(data_path) if not file.endswith('_telemetry.csv') and not file.startswith('srad')]:
    csv_full_path = os.path.join(data_path, csv_name)
    # print(csv_full_path)
    df = pd.read_csv(csv_full_path)
    df['Range'] = int(csv_name.split('_')[1].split('.')[0])
    df['App_name'] = mapping_table[csv_name.split('_')[0]]

    data_sheet=pd.concat([data_sheet, df], ignore_index=True)

# %% [markdown]
# ## Fixing the set of computed metrics across all the experiments

# %% [markdown]
# ### I want to check if the number of Kernel Injection (Range) affects the number of run sessions.

# %%
for label in sorted(data_sheet['Range'].unique()):
    print("--------------------------------------------------------------------")
    print(f'Number of times a kernel is executed for metric computation: {label}') 
    print(f"Instances: {len(data_sheet[data_sheet['Range']==label])}")
# Out:
# --------------------------------------------------------------------
# Number of times a kernel is executed for metric computation: 1
# Instances: 33756
# --------------------------------------------------------------------
# Number of times a kernel is executed for metric computation: 3
# Instances: 34080
# --------------------------------------------------------------------
# Number of times a kernel is executed for metric computation: 5
# Instances: 34224
# --------------------------------------------------------------------
# Number of times a kernel is executed for metric computation: 7
# Instances: 33924
# --------------------------------------------------------------------
# Number of times a kernel is executed for metric computation: 10
# Instances: 34080
# --------------------------------------------------------------------
# Number of times a kernel is executed for metric computation: 15
# Instances: 34080
# --------------------------------------------------------------------
# Number of times a kernel is executed for metric computation: 20
# Instances: 34224
# --------------------------------------------------------------------
# Number of times a kernel is executed for metric computation: 30
# Instances: 34248
# --------------------------------------------------------------------
# Number of times a kernel is executed for metric computation: 50
# Instances: 34260
# --------------------------------------------------------------------
# Number of times a kernel is executed for metric computation: 80
# Instances: 34296
# --------------------------------------------------------------------
# Number of times a kernel is executed for metric computation: 100
# Instances: 34308

# %% [markdown]
# ### Apparently not

# %% [markdown]
# ### Thus, it must be dependent only on the application complexity

# %%
for label in mapping_table.values():
    print("--------------------------------------------------------------------")
    print(f'App name: {label}') 
    print(f"Instances: {len(data_sheet[data_sheet['App_name']==label])}")
# Out:
# --------------------------------------------------------------------
# App name: Backpropagation algorithm
# Instances: 264
# --------------------------------------------------------------------
# App name: Gaussian Elimination
# Instances: 270072
# --------------------------------------------------------------------
# App name: Stream Cluster
# Instances: 0
# --------------------------------------------------------------------
# App name: Lenet5
# Instances: 71904
# --------------------------------------------------------------------
# App name: GPU-burn
# Instances: 33240

# %% [markdown]
# ### Considerations
# 1. Complexity does not imply stress
# 2. I think that the complexity is due also to the number of kernels that the application comprises
#
# TODO: look at Future works

# %% [markdown]
# ### Available data

# %%
location_mapping={
    'gpc': 'GPU Processing Cluster',
    'gr': 'Graphics Engine',
    'sm': 'Streaming Multiprocessor',
    'dramc': 'Dynamic RAM Controller',
    'pcie': 'PCI Express'
}
data_sheet['location'].unique()
# Out:
# array(['gpc', 'gr', 'tpc', 'sm', 'dramc', 'pcie'], dtype=object)

# %%
data_sheet['HR_location'] = data_sheet['location'].map(location_mapping)
data_sheet.drop('location', axis=1, inplace=True)

# %%
len(data_sheet)
# Out:
# 375480

# %%
metric_event_mapping= {
    'cycles_elapsed': 'Total elapsed cycles [Cycles/s]',
    'cycles_active': 'Active cycles [Cycles/s]',
    'warps_active_realtime': 'Active warps [%]',
    'inst_executed': 'Executed instructions [%]',
    'ipe_tensor_cycles_active':'Tensor Cores Active Cycles [%]',
    'sectors_op_read':'Read Sectors [%]',
    'sectors_op_wtite':'Written Sectors [%]',
    'read_bytes':'Read bytes (CPU to GPU) [%]',
    'write_bytes':'Written bytes (GPU to CPU) [%]',
}
data_sheet['metric_name'].unique()

# pcie metrics are computed in a different way and it is better to keep them as a percentace
data_sheet = data_sheet[~((data_sheet['rollup_operation'] == 'sum') & (data_sheet['metric_name'] == 'read_bytes'))]

# %%
# It is a useless column, we can drop it
data_sheet = data_sheet.drop('rollup_operation', axis=1)

# %%
data_sheet['HR_metric_name'] = data_sheet['metric_name'].map(metric_event_mapping)
data_sheet.drop('metric_name', axis=1, inplace=True)

# %% [markdown]
# ### Let's fix for a second the Number of times a kernel is executed for metric computations to 1

# %%
data_sheet['Range'].dtypes
# Out:
# dtype('int64')

# %%
data_sheet_3 = data_sheet[data_sheet['Range']==3]

# %%
data_sheet_3
# Out:
#         session_id  duration_ms  range_name  metric_value  Range  \
# 37068            1        743.0           0  1.265110e+09      3
# 37069            1        743.0           1  1.230590e+09      3
# 37070            1        743.0           2  1.231130e+09      3
# 37071            1        743.0           0  1.000000e+02      3
# 37072            1        743.0           1  1.000000e+02      3
# ...            ...          ...         ...           ...    ...
# 265924         682          NaN           1  2.440270e+01      3
# 265925         682          NaN           2  2.905180e-01      3
# 265929         682          NaN           0  5.632000e+03      3
# 265930         682          NaN           1  5.632000e+03      3
# 265931         682          NaN           2  5.120000e+03      3
#
#                     App_name             HR_location  \
# 37068               GPU-burn  GPU Processing Cluster
# 37069               GPU-burn  GPU Processing Cluster
# 37070               GPU-burn  GPU Processing Cluster
# 37071               GPU-burn         Graphics Engine
# 37072               GPU-burn         Graphics Engine
# ...                      ...                     ...
# 265924  Gaussian Elimination             PCI Express
# 265925  Gaussian Elimination             PCI Express
# 265929  Gaussian Elimination             PCI Express
# 265930  Gaussian Elimination             PCI Express
# 265931  Gaussian Elimination             PCI Express
#
#                          HR_metric_name
# 37068   Total elapsed cycles [Cycles/s]
# 37069   Total elapsed cycles [Cycles/s]
# 37070   Total elapsed cycles [Cycles/s]
# 37071          Active cycles [Cycles/s]
# 37072          Active cycles [Cycles/s]
# ...                                 ...
# 265924   Written bytes (GPU to CPU) [%]
# 265925   Written bytes (GPU to CPU) [%]
# 265929   Written bytes (GPU to CPU) [%]
# 265930   Written bytes (GPU to CPU) [%]
# 265931   Written bytes (GPU to CPU) [%]
#
# [31240 rows x 8 columns]

# %%
data_sheet['HR_metric_name'].unique()
# Out:
# array(['Total elapsed cycles [Cycles/s]', 'Active cycles [Cycles/s]',
#        'Active warps [%]', 'Executed instructions [%]', nan,
#        'Read Sectors [%]', 'Read bytes (CPU to GPU) [%]',
#        'Written bytes (GPU to CPU) [%]'], dtype=object)

# %% [markdown]
# ### Regardless of the application I want to see the correlation within the columns

# %%
df_l2_3 = data_sheet_3[data_sheet_3['HR_location']=='GPU Processing Cluster']
df_sm_3 = data_sheet_3[data_sheet_3['HR_location']=='Graphics Engine']
df_smsp_3 = data_sheet_3[data_sheet_3['HR_location']=='Streaming Multiprocessor']
df_sys_3 = data_sheet_3[data_sheet_3['HR_location']=='PCI Express']
df_dram_3 = data_sheet_3[data_sheet_3['HR_location']=='Dynamic RAM Controller']

dfs = {
    'GPU Processing Cluster': df_l2_3, 
    'Graphics Engine': df_sm_3, 
    'Streaming Multiprocessor': df_smsp_3, 
    'PCI Express': df_sys_3, 
    'Dynamic RAM Controller': df_dram_3
    }

# %%
df_pivot_l2_3 = df_l2_3.pivot_table(
    index=["session_id", "HR_location", "range_name", "Range", "App_name"],
    columns="HR_metric_name",
    values="metric_value"
).reset_index()

df_pivot_sm_3 = df_sm_3.pivot_table(
    index=["session_id", "HR_location", "range_name", "Range", "App_name"],
    columns="HR_metric_name",
    values="metric_value"
).reset_index()

df_pivot_smsp_3 = df_smsp_3.pivot_table(
    index=["session_id", "HR_location", "range_name", "Range", "App_name"],
    columns="HR_metric_name",
    values="metric_value"
).reset_index()

df_pivot_sys_3 = df_sys_3.pivot_table(
    index=["session_id", "HR_location", "range_name", "Range", "App_name"],
    columns="HR_metric_name",
    values="metric_value"
).reset_index()

df_pivot_dram_3 = df_dram_3.pivot_table(
    index=["session_id", "HR_location", "range_name", "Range", "App_name"],
    columns="HR_metric_name",
    values="metric_value"
).reset_index()

pivot_dfs = {
    'GPU Processing Cluster': df_pivot_l2_3, 
    'Graphics Engine': df_pivot_sm_3, 
    'Streaming Multiprocessor': df_pivot_smsp_3, 
    'PCI Express': df_pivot_sys_3, 
    'Dynamic RAM Controller': df_pivot_dram_3
    }

# %%
metric_full_name = data_sheet_3['HR_location'] +' '+ data_sheet_3['HR_metric_name']
metric_full_name
# Out:
# 37068     GPU Processing Cluster Total elapsed cycles [C...
# 37069     GPU Processing Cluster Total elapsed cycles [C...
# 37070     GPU Processing Cluster Total elapsed cycles [C...
# 37071              Graphics Engine Active cycles [Cycles/s]
# 37072              Graphics Engine Active cycles [Cycles/s]
#                                 ...
# 265924           PCI Express Written bytes (GPU to CPU) [%]
# 265925           PCI Express Written bytes (GPU to CPU) [%]
# 265929           PCI Express Written bytes (GPU to CPU) [%]
# 265930           PCI Express Written bytes (GPU to CPU) [%]
# 265931           PCI Express Written bytes (GPU to CPU) [%]
# Length: 31240, dtype: object

# %%
pivot_dfs
# Out:
# {'GPU Processing Cluster': HR_metric_name  session_id             HR_location  range_name  Range  \
#  0                        1  GPU Processing Cluster           0      3
#  1                        1  GPU Processing Cluster           0      3
#  2                        1  GPU Processing Cluster           0      3
#  3                        1  GPU Processing Cluster           0      3
#  4                        1  GPU Processing Cluster           1      3
#  ...                    ...                     ...         ...    ...
#  2835                   681  GPU Processing Cluster           1      3
#  2836                   681  GPU Processing Cluster           2      3
#  2837                   682  GPU Processing Cluster           0      3
#  2838                   682  GPU Processing Cluster           1      3
#  2839                   682  GPU Processing Cluster           2      3
#
#  HR_metric_name                   App_name  Total elapsed cycles [Cycles/s]
#  0               Backpropagation algorithm                     1.584170e+09
#  1                                GPU-burn                     1.265110e+09
#  2                    Gaussian Elimination                     1.618880e+09
#  3                                  Lenet5                     1.510510e+09
#  4               Backpropagation algorithm                     1.645750e+09
#  ...                                   ...                              ...
#  2835                 Gaussian Elimination                     2.039010e+09
#  2836                 Gaussian Elimination                     1.958780e+09
#  2837                 Gaussian Elimination                     2.038630e+09
#  2838                 Gaussian Elimination                     1.951610e+09
#  2839                 Gaussian Elimination                     2.038720e+09
#
#  [2840 rows x 6 columns],
#  'Graphics Engine': HR_metric_name  session_id      HR_location  range_name  Range  \
#  0                        1  Graphics Engine           0      3
#  1                        1  Graphics Engine           0      3
#  2                        1  Graphics Engine           0      3
#  3                        1  Graphics Engine           0      3
#  4                        1  Graphics Engine           1      3
#  ...                    ...              ...         ...    ...
#  2835                   681  Graphics Engine           1      3
#  2836                   681  Graphics Engine           2      3
#  2837                   682  Graphics Engine           0      3
#  2838                   682  Graphics Engine           1      3
#  2839                   682  Graphics Engine           2      3
#
#  HR_metric_name                   App_name  Active cycles [Cycles/s]
#  0               Backpropagation algorithm                     100.0
#  1                                GPU-burn                     100.0
#  2                    Gaussian Elimination                     100.0
#  3                                  Lenet5                     100.0
#  4               Backpropagation algorithm                     100.0
#  ...                                   ...                       ...
#  2835                 Gaussian Elimination                     100.0
#  2836                 Gaussian Elimination                     100.0
#  2837                 Gaussian Elimination                     100.0
#  2838                 Gaussian Elimination                     100.0
#  2839                 Gaussian Elimination                     100.0
#
#  [2840 rows x 6 columns],
#  'Streaming Multiprocessor': HR_metric_name  session_id               HR_location  range_name  Range  \
#  0                        1  Streaming Multiprocessor           0      3
#  1                        1  Streaming Multiprocessor           0      3
#  2                        1  Streaming Multiprocessor           0      3
#  3                        1  Streaming Multiprocessor           0      3
#  4                        1  Streaming Multiprocessor           1      3
#  ...                    ...                       ...         ...    ...
#  2835                   681  Streaming Multiprocessor           1      3
#  2836                   681  Streaming Multiprocessor           2      3
#  2837                   682  Streaming Multiprocessor           0      3
#  2838                   682  Streaming Multiprocessor           1      3
#  2839                   682  Streaming Multiprocessor           2      3
#
#  HR_metric_name                   App_name  Active cycles [Cycles/s]  \
#  0               Backpropagation algorithm                  97.01080
#  1                                GPU-burn                  99.89780
#  2                    Gaussian Elimination                   4.97761
#  3                                  Lenet5                  71.58880
#  4               Backpropagation algorithm                  99.27850
#  ...                                   ...                       ...
#  2835                 Gaussian Elimination                  24.30060
#  2836                 Gaussian Elimination                   2.28558
#  2837                 Gaussian Elimination                  23.78860
#  2838                 Gaussian Elimination                   2.40882
#  2839                 Gaussian Elimination                  24.25060
#
#  HR_metric_name  Executed instructions [%]
#  0                               51.213200
#  1                               74.679600
#  2                                0.495025
#  3                               28.664800
#  4                                3.848320
#  ...                                   ...
#  2835                             3.010530
#  2836                             0.114209
#  2837                             3.010220
#  2838                             0.112240
#  2839                             2.992920
#
#  [2840 rows x 7 columns],
#  'PCI Express': HR_metric_name  session_id  HR_location  range_name  Range  \
#  0                        1  PCI Express           0      3
#  1                        1  PCI Express           0      3
#  2                        1  PCI Express           0      3
#  3                        1  PCI Express           0      3
#  4                        1  PCI Express           1      3
#  ...                    ...          ...         ...    ...
#  2835                   681  PCI Express           1      3
#  2836                   681  PCI Express           2      3
#  2837                   682  PCI Express           0      3
#  2838                   682  PCI Express           1      3
#  2839                   682  PCI Express           2      3
#
#  HR_metric_name                   App_name  Read bytes (CPU to GPU) [%]  \
#  0               Backpropagation algorithm                     0.000000
#  1                                GPU-burn                     0.000124
#  2                    Gaussian Elimination                     0.000000
#  3                                  Lenet5                     0.000000
#  4               Backpropagation algorithm                     0.000000
#  ...                                   ...                          ...
#  2835                 Gaussian Elimination                     0.029223
#  2836                 Gaussian Elimination                     0.000000
#  2837                 Gaussian Elimination                     0.000000
#  2838                 Gaussian Elimination                     0.000000
#  2839                 Gaussian Elimination                     0.029052
#
#  HR_metric_name  Written bytes (GPU to CPU) [%]
#  0                                  2560.317724
#  1                                  4352.000132
#  2                                  2565.336600
#  3                                  2818.657200
#  4                                  2560.067173
#  ...                                        ...
#  2835                               2560.146114
#  2836                               2571.261250
#  2837                               2816.160716
#  2838                               2828.201350
#  2839                               2560.145259
#
#  [2840 rows x 7 columns],
#  'Dynamic RAM Controller': HR_metric_name  session_id             HR_location  range_name  Range  \
#  0                        1  Dynamic RAM Controller           0      3
#  1                        1  Dynamic RAM Controller           0      3
#  2                        1  Dynamic RAM Controller           0      3
#  3                        1  Dynamic RAM Controller           0      3
#  4                        1  Dynamic RAM Controller           1      3
#  ...                    ...                     ...         ...    ...
#  2835                   681  Dynamic RAM Controller           1      3
#  2836                   681  Dynamic RAM Controller           2      3
#  2837                   682  Dynamic RAM Controller           0      3
#  2838                   682  Dynamic RAM Controller           1      3
#  2839                   682  Dynamic RAM Controller           2      3
#
#  HR_metric_name                   App_name  Read Sectors [%]
#  0               Backpropagation algorithm          0.010043
#  1                                GPU-burn         53.106400
#  2                    Gaussian Elimination          0.163901
#  3                                  Lenet5          0.039177
#  4               Backpropagation algorithm          0.003105
#  ...                                   ...               ...
#  2835                 Gaussian Elimination          0.000000
#  2836                 Gaussian Elimination          0.000000
#  2837                 Gaussian Elimination          0.000000
#  2838                 Gaussian Elimination          0.000000
#  2839                 Gaussian Elimination          0.000000
#
#  [2840 rows x 6 columns]}

# %%
fig, ax = plt.subplots(5,2,figsize=(10,30))
for pivot_df_idx in range(len(list(pivot_dfs.values()))):
    HR_location = list(pivot_dfs.keys())[pivot_df_idx]
    # print(pivot_dfs[HR_location].select_dtypes(include=['float64']))
    # data_to_corr = pivot_dfs[HR_location][cols_to_corr]
    # target_data = data_to_corr.drop('HR_location', axis = 1)
    data_to_corr = pivot_dfs[HR_location].select_dtypes(include=['float64'])
    matrix = data_to_corr.corr()
    matrix.boxplot(ax=ax[pivot_df_idx][1])
    sns.heatmap(matrix, annot=False, cmap='coolwarm', ax=ax[pivot_df_idx][0])
    ax[pivot_df_idx][0].set_title(f"Grouped per: {HR_location}", fontsize=20, pad=40)
    ax[pivot_df_idx][0].grid()
    ax[pivot_df_idx][0].set_xlabel('Performance counter', fontsize=15)
    ax[pivot_df_idx][0].set_ylabel('Performance counter', fontsize=15)
    ax[pivot_df_idx][1].tick_params(axis='x', labelrotation=90, labelsize=13)
    ax[pivot_df_idx][0].tick_params(axis='x', labelrotation=90, labelsize=13)
    ax[pivot_df_idx][0].set_xticklabels([])
    ax[pivot_df_idx][1].set_xticklabels([])
    ax[pivot_df_idx][0].set_xlabel('')
# Out:
# /home/bepi/anaconda3/envs/gpustress/lib/python3.10/site-packages/seaborn/matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# /home/bepi/anaconda3/envs/gpustress/lib/python3.10/site-packages/seaborn/matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)

# %% [markdown]
# ### Stress evaluation

# %%
hue_order = ['Backpropagation algorithm', 'Gaussian Elimination', 'Lenet5', 'GPU-burn']

# %%
fig, ax = plt.subplots(5,1,figsize=(10,50))
for pivot_df_idx in range(len(list(dfs.values()))):
    HR_location = list(dfs.keys())[pivot_df_idx]
    # data_to_corr = dfs[HR_location].select_dtypes(include=['float64'])
    sns.barplot(data = dfs[HR_location], x='HR_metric_name', y='metric_value', hue='App_name', ax = ax[pivot_df_idx], hue_order=hue_order)
    # ax[pivot_df_idx].set_title(f"Grouped per: {HR_location}", fontsize=20, loc='right')
    ax[pivot_df_idx].text(1.05, 1.0, f'Grouped per: \n {HR_location}', transform=ax[pivot_df_idx].transAxes,
         ha='left', va='top', fontsize=15)
    ax[pivot_df_idx].grid()
    # ax[pivot_df_idx].set_yscale('log')
    ax[pivot_df_idx].set_xlabel('Performance counter', fontsize=15)
    ax[pivot_df_idx].set_ylabel('Performance counter', fontsize=15)
    ax[pivot_df_idx].tick_params(axis='x', labelrotation=90, labelsize=13)
    # ax[pivot_df_idx].set_xticklabels([])
    ax[pivot_df_idx].set_xlabel('')
plt.tight_layout()

# %%
fig, ax = plt.subplots(8,1,figsize=(10,60))
for metric_idx in range(len(data_sheet_3['HR_metric_name'].unique())):
    metric_name = data_sheet_3['HR_metric_name'].unique()[metric_idx]
    data = data_sheet_3[data_sheet_3['HR_metric_name'] == metric_name]
    # HR_location=data['HR_location'].unique()[0]
    sns.lineplot(data = data, x='session_id', y='metric_value', hue='App_name', ax = ax[metric_idx], ci=False, hue_order=hue_order)
    sns.scatterplot(data = data, x='session_id', y='metric_value', hue='App_name', ax = ax[metric_idx], alpha=0.15, legend=False, hue_order=hue_order)
    ax[metric_idx].set_title(f"{HR_location} {metric_name}", fontsize=20, loc='right')
    # ax[metric_idx].text(1.05, 1.0, f'Grouped per: \n {HR_location}', transform=ax[metric_idx].transAxes,
    #      ha='left', va='top', fontsize=15)
    ax[metric_idx].grid()
    # ax[metric_idx].set_yscale('log')
    ax[metric_idx].set_xlabel('Session', fontsize=15)
    ax[metric_idx].set_ylabel('Events number', fontsize=15)
    ax[metric_idx].tick_params(axis='x', labelrotation=90, labelsize=13)
    # ax[df_idx].set_xticklabels([])
plt.tight_layout()
# Out:
# /tmp/ipykernel_20602/1569094043.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.lineplot(data = data, x='session_id', y='metric_value', hue='App_name', ax = ax[metric_idx], ci=False, hue_order=hue_order)
# /tmp/ipykernel_20602/1569094043.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.lineplot(data = data, x='session_id', y='metric_value', hue='App_name', ax = ax[metric_idx], ci=False, hue_order=hue_order)
# /tmp/ipykernel_20602/1569094043.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.lineplot(data = data, x='session_id', y='metric_value', hue='App_name', ax = ax[metric_idx], ci=False, hue_order=hue_order)
# /tmp/ipykernel_20602/1569094043.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.lineplot(data = data, x='session_id', y='metric_value', hue='App_name', ax = ax[metric_idx], ci=False, hue_order=hue_order)
# /tmp/ipykernel_20602/1569094043.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.lineplot(data = data, x='session_id', y='metric_value', hue='App_name', ax = ax[metric_idx], ci=False, hue_order=hue_order)
# /tmp/ipykernel_20602/1569094043.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.lineplot(data = data, x='session_id', y='metric_value', hue='App_name', ax = ax[metric_idx], ci=False, hue_order=hue_order)
# /tmp/ipykernel_20602/1569094043.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.lineplot(data = data, x='session_id', y='metric_value', hue='App_name', ax = ax[metric_idx], ci=False, hue_order=hue_order)
# /tmp/ipykernel_20602/1569094043.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.lineplot(data = data, x='session_id', y='metric_value', hue='App_name', ax = ax[metric_idx], ci=False, hue_order=hue_order)

# %%
fig, ax = plt.subplots(1,1,figsize=(10,7))
HR_location=data['HR_location'].unique()[0]
sns.boxplot(data, y='duration_ms', hue='App_name', ax = ax, hue_order=hue_order)
ax.grid()
ax.set_xlabel('', fontsize=15)
# Out:
# Text(0.5, 0, '')

# %%
fig, ax = plt.subplots(1,1,figsize=(10,7))
HR_location=data['HR_location'].unique()[0]
sns.lineplot(data, x='session_id' ,y='duration_ms', hue='App_name', ax = ax, hue_order=hue_order)
ax.grid()
ax.set_xlabel('', fontsize=15)
# Out:
# Text(0.5, 0, '')

# %% [markdown]
# ### Final remarks
#
# ### Future works
# 1. Use the correlation ID to correlate instructions with SASS code
# 2. Explore the possibility to use sass_source_map or sass_metrics
# 3.
