# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
data_path = '../../data/postprocessed/INPUTSSA/'

mapping_table = {
    'gpuburn5min0': 'Single alternative',
    'gpuburn5min1': 'Couple alternative',
    'gpuburn5min2': 'Triple alternative',
    'gpuburn5min3': 'Quadruple alternative',
    'gpuburn5min4': 'Quintuple alternative',
    'gpuburn5minRandom1': 'Original GPU-burn'
}

data_sheet = pd.DataFrame()
for csv_name in [file for file in os.listdir(data_path) if (file.endswith('_telemetry.csv') and ('NN50Perc' in file or '5min' in file))]:
    csv_full_path = os.path.join(data_path, csv_name)
    print(csv_full_path)
    df = pd.read_csv(csv_full_path)
    df['Index'] = range(len(df))
    df['progress'] = df['Index'].transform(
        lambda x: 100 * (x - x.min()) / (x.max() - x.min()) if x.max() > x.min() else 0)
    df['Range'] = int(csv_name.split('_')[1].split('_')[0])
    print(csv_name.split('_')[0] + csv_name.split('_')[1])
    
    df['App_name'] = mapping_table[csv_name.split('_')[0] + csv_name.split('_')[1]]

    data_sheet=pd.concat([data_sheet, df], ignore_index=True)
# Out:
# ../../data/postprocessed/INPUTSSA/gpuburn5minRandom_1_telemetry.csv
# gpuburn5minRandom1
# ../../data/postprocessed/INPUTSSA/gpuburn5min_1_1_telemetry.csv
# gpuburn5min1
# ../../data/postprocessed/INPUTSSA/gpuburn5min_2_1_telemetry.csv
# gpuburn5min2
# ../../data/postprocessed/INPUTSSA/gpuburn5min_3_1_telemetry.csv
# gpuburn5min3
# ../../data/postprocessed/INPUTSSA/gpuburn5min_0_1_telemetry.csv
# gpuburn5min0
# ../../data/postprocessed/INPUTSSA/gpuburn5min_4_1_telemetry.csv
# gpuburn5min4

# %%
data_sheet.columns
# Out:
# Index(['timestamp_ns', 'gpu_index', 'name', 'temperature_C',
#        'util_gpu_percent', 'util_mem_percent', 'mem_total_MB', 'mem_used_MB',
#        'mem_free_MB', 'clock_sm_MHz', 'clock_mem_MHz', 'clock_graphics_MHz',
#        'fan_speed_percent', 'power_draw_W', 'ecc_volatile_corrected',
#        'ecc_volatile_uncorrected', 'ecc_aggregate_corrected',
#        'ecc_aggregate_uncorrected', 'total_energy_mJ', 'Index', 'progress',
#        'Range', 'App_name'],
#       dtype='object')

# %% [markdown]
# ### Drop meaningless columns

# %%
data_sheet.describe()
# Out:
#        gpu_index  temperature_C  util_gpu_percent  util_mem_percent  \
# count     1998.0    1998.000000       1998.000000       1998.000000
# mean         0.0      58.914915         91.570571         13.504505
# std          0.0       4.855320         23.217436         11.344946
# min          0.0      38.000000          0.000000          0.000000
# 25%          0.0      56.000000         98.000000          2.000000
# 50%          0.0      60.000000         99.000000         17.000000
# 75%          0.0      63.000000        100.000000         20.000000
# max          0.0      66.000000        100.000000        100.000000
#
#        mem_total_MB  mem_used_MB  mem_free_MB  clock_sm_MHz  clock_mem_MHz  \
# count        1998.0  1998.000000  1998.000000   1998.000000    1998.000000
# mean         8188.0  7428.908909   759.091091   1574.415916    5360.668168
# std             0.0  1791.657996  1791.657996    408.275747     989.008619
# min          8188.0   353.000000   253.000000     26.000000     405.000000
# 25%          8188.0  7933.000000   255.000000   1395.000000    5500.000000
# 50%          8188.0  7933.000000   255.000000   1485.000000    5500.000000
# 75%          8188.0  7933.000000   255.000000   1935.000000    5500.000000
# max          8188.0  7935.000000  7835.000000   2040.000000    8000.000000
#
#        clock_graphics_MHz  fan_speed_percent  power_draw_W  \
# count         1998.000000             1998.0   1998.000000
# mean          1574.415916               -1.0     32.555071
# std            408.275747                0.0      6.793807
# min             26.000000               -1.0      1.851000
# 25%           1395.000000               -1.0     32.663000
# 50%           1485.000000               -1.0     34.741500
# 75%           1935.000000               -1.0     34.966000
# max           2040.000000               -1.0     39.019000
#
#        ecc_volatile_corrected  ecc_volatile_uncorrected  \
# count                  1998.0                    1998.0
# mean                     -1.0                      -1.0
# std                       0.0                       0.0
# min                      -1.0                      -1.0
# 25%                      -1.0                      -1.0
# 50%                      -1.0                      -1.0
# 75%                      -1.0                      -1.0
# max                      -1.0                      -1.0
#
#        ecc_aggregate_corrected  ecc_aggregate_uncorrected  total_energy_mJ  \
# count                   1998.0                     1998.0     1.998000e+03
# mean                      -1.0                       -1.0     1.015951e+08
# std                        0.0                        0.0     5.951721e+07
# min                       -1.0                       -1.0     3.103860e+05
# 25%                       -1.0                       -1.0     4.964966e+07
# 50%                       -1.0                       -1.0     1.021023e+08
# 75%                       -1.0                       -1.0     1.527554e+08
# max                       -1.0                       -1.0     2.077703e+08
#
#              Index     progress        Range
# count  1998.000000  1998.000000  1998.000000
# mean    166.009510    50.000000     1.834334
# std      96.168868    28.961582     1.343425
# min       0.000000     0.000000     0.000000
# 25%      83.000000    24.924240     1.000000
# 50%     166.000000    50.000000     1.000000
# 75%     249.000000    75.075760     3.000000
# max     334.000000   100.000000     4.000000

# %%
metrics_map = {
    'temperature_C':'Temperature [°C]',
    'util_gpu_percent': 'GPU Utilization [%]',
    'util_mem_percent':'GPU Memory Utilization [%]',
    'mem_used_MB':'Used Memory [MB]', 
    'mem_free_MB':'Free Memory [MB]', 
    'clock_sm_MHz':'Streaming Multiprocessor Clock Frequency [MHz]', 
    'clock_mem_MHz':'Memory Clock Frequency [MHz]', 
    'power_draw_W':'GPU Power Consumption [W]',
    'total_energy_mJ': 'Energy'
}
data_sheet.rename(columns=metrics_map, inplace=True)
# data_sheet['timestamp_s'] = data_sheet['timestamp_ns'] / 1e9

# %%
data_sheet.drop(labels=['ecc_volatile_uncorrected', 'ecc_volatile_uncorrected', 'ecc_aggregate_corrected', 'ecc_aggregate_uncorrected', 'fan_speed_percent'], axis=1, inplace=True)

# %%
# hue_order = ['Backpropagation algorithm', 'Gaussian Elimination', 'Lenet5', 'GPU-burn']
def plot_gpu_metric(df, column_name):
    fig, ax = plt.subplots(figsize=(10, 5))
    data_sheet = df[df['App_name']=='Single alternative']
    # data_sheet[f'{column_name}_diff'] = data_sheet.groupby('App_name')[column_name].diff()
    if column_name == 'Energy':
        data_sheet[f'{column_name}_diff'] = data_sheet[f'{column_name}_diff']/1000
    sns.lineplot(data=data_sheet, x='Index', y=f'{column_name}_diff', ax=ax)
    ax.set_title(f'{column_name} over time', fontsize=14)
    ax.set_xlabel('Time (s)', fontsize=12)
    ax.set_ylabel(column_name, fontsize=12)
    ax.grid(True, linestyle='--', alpha=0.7)
    ax.legend()
    # ax.set_xlim(right=5000)
    plt.show()

# %%
for column in metrics_map.values():
    plot_gpu_metric(data_sheet, column)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 for column in metrics_map.values():
# ----> 2     plot_gpu_metric(data_sheet, column)
#
# Cell In[7], line 8, in plot_gpu_metric(df, column_name)
#       6 if column_name == 'Energy':
#       7     data_sheet[f'{column_name}_diff'] = data_sheet[f'{column_name}_diff']/1000
# ----> 8 sns.lineplot(data=data_sheet, x='Index', y=f'{column_name}_diff', ax=ax)
#       9 ax.set_title(f'{column_name} over time', fontsize=14)
#      10 ax.set_xlabel('Time (s)', fontsize=12)
#
# File ~/anaconda3/envs/gpustress/lib/python3.10/site-packages/seaborn/relational.py:485, in lineplot(data, x, y, hue, size, style, units, weights, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     471 def lineplot(
#     472     data=None, *,
#     473     x=None, y=None, hue=None, size=None, style=None, units=None, weights=None,
#    (...)
#     481
#     482     # Handle deprecation of ci parameter
#     483     errorbar = _deprecate_ci(errorbar, ci)
# --> 485     p = _LinePlotter(
#     486         data=data,
#     487         variables=dict(
#     488             x=x, y=y, hue=hue, size=size, style=style, units=units, weight=weights
#     489         ),
#     490         estimator=estimator, n_boot=n_boot, seed=seed, errorbar=errorbar,
#     491         sort=sort, orient=orient, err_style=err_style, err_kws=err_kws,
#     492         legend=legend,
#     493     )
#     495     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     496     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# File ~/anaconda3/envs/gpustress/lib/python3.10/site-packages/seaborn/relational.py:216, in _LinePlotter.__init__(self, data, variables, estimator, n_boot, seed, errorbar, sort, orient, err_style, err_kws, legend)
#     202 def __init__(
#     203     self, *,
#     204     data=None, variables={},
#    (...)
#     210     # the kind of plot to draw, but for the time being we need to set
#     211     # this information so the SizeMapping can use it
#     212     self._default_size_range = (
#     213         np.r_[.5, 2] * mpl.rcParams["lines.linewidth"]
#     214     )
# --> 216     super().__init__(data=data, variables=variables)
#     218     self.estimator = estimator
#     219     self.errorbar = errorbar
#
# File ~/anaconda3/envs/gpustress/lib/python3.10/site-packages/seaborn/_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File ~/anaconda3/envs/gpustress/lib/python3.10/site-packages/seaborn/_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File ~/anaconda3/envs/gpustress/lib/python3.10/site-packages/seaborn/_core/data.py:58, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
#      57     data = handle_data_source(data)
# ---> 58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#      61     self.names = names
#
# File ~/anaconda3/envs/gpustress/lib/python3.10/site-packages/seaborn/_core/data.py:232, in PlotData._assign_variables(self, data, variables)
#     230     else:
#     231         err += "An entry with this name does not appear in `data`."
# --> 232     raise ValueError(err)
#     234 else:
#     235
#     236     # Otherwise, assume the value somehow represents data
#     237
#     238     # Ignore empty data structures
#     239     if isinstance(val, Sized) and len(val) == 0:
#
# ValueError: Could not interpret value `Temperature [°C]_diff` for `y`. An entry with this name does not appear in `data`.

# %% [markdown]
# ### To me it seems that the application is run at maximum 7 times to satisfy experimental conditions

# %%
# hue_order = ['Backpropagation algorithm', 'Gaussian Elimination', 'Lenet5', 'GPU-burn']
def plot_gpu_metric(df, range_lab):
    data = df[df['Range']==range_lab]
    # data['timestamp_s'] = data['timestamp_ns'] / 1e9
    # data['timestamp_s'] = data.groupby('App_name')['timestamp_s'].diff()
    fig, ax = plt.subplots(figsize=(10, 5))
    sns.lineplot(data=data, x='Index', y='Temperature [°C]', ax=ax, hue='App_name')
    ax.set_title(f'Temperature [°C] over time for range = {range_lab}', fontsize=14)
    ax.set_xlabel('Time (s)', fontsize=12)
    ax.set_ylabel('Temperature [°C]', fontsize=12)
    ax.grid(True, linestyle='--', alpha=0.7)
    ax.legend()
    # ax.set_xlim(right=5000)
    plt.show()

# %%
for range_lab in sorted(data_sheet['Range'].unique()):
    plot_gpu_metric(data_sheet, range_lab)
